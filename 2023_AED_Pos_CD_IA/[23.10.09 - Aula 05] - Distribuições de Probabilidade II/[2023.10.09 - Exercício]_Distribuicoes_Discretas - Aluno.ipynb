# %% [markdown]
# # **Pós-Graduação: Ciência de Dados e Inteligência Artificial.**
# ## **AED - Análise Estatística de Dados**
# ---
# ## **Prof. Jones E. Egydio**
#
# * [LinkedIn](https://www.linkedin.com/in/jones-egydio-msc-3300359)
# * [Lattes](http://lattes.cnpq.br/7379006374125031)
# * [GitHub](https://github.com/jegydio/Postgraduate.git)
# * jones.egydio@maua.br
#
# ---
#
# **09.10.2023 - Aula 05 - Exercício Extra**
#
# ---

# %% [markdown]
# # **Setup**

# %%
# Bibliotecas básicas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Funções**

# %%
def histograma(coluna, media, DP, bins):
    """Função para plotar o histograma de uma coluna."""

    df_P[coluna].hist(bins = bins,figsize=(8, 8), legend=True, grid =False)
    plt.axvline(media, color='k', linestyle='dashed', linewidth=3)
    plt.axvline(media+DP, color='r', linestyle='dashed', linewidth=3)
    plt.axvline(media-DP, color='r', linestyle='dashed', linewidth=3);

# %% [markdown]
# # **Dados - Premier League**

# %% [markdown]
# ## **1 - Dados baixados direto no Colab**

# %%
# %%capture
# !gdown 1ZQS9D7bmpwSzYNaZ1I-rtUO7iFLIAY-Q
# !gdown 1-V0XphfUTo4CIuNRn8J84zOrrWEhtJR7
# !gdown 18uzVYgiChiD9IJ_C4tLLTvOrR1M5qoZk
# !gdown 1Avq9JGQ2O7PGbojz-8U_8-r-8PbnUQvt

# %%
# Lendo os dados
### Dados da Liga - L
df_L = pd.read_csv('england-premier-league-league-2018-to-2019-stats.csv')

### Dados das partidas - P
df_P = pd.read_csv('england-premier-league-matches-2018-to-2019-stats.csv')

### Dados dos jogadores - J
df_J = pd.read_csv('england-premier-league-players-2018-to-2019-stats.csv')

### Dados dos times - T
df_T = pd.read_csv('england-premier-league-teams-2018-to-2019-stats.csv')

# %% [markdown]
# # **Exploração**

# %% [markdown]
# **Objetivos:**
#
# Realizar uma análise estatística com base no dados da Premier League e verificar as distribuições de probabilidade teórica e real.
#
# Análise possíveis por jogo:
#
# 1.   Número de gols por partida
# 2.   Número de chutes no gol
# 3.   Número de cartões amarelos
#
# **Pergunta:** Qual a **chance** de que em um jogo qualquer o número de gols seja superior a 3?

# %%
df_P.sample(5)
# Out:
#       timestamp               date_GMT    status  attendance  \
# 167  1544967000   Dec 16 2018 - 1:30pm  complete         NaN
# 317  1554317100   Apr 03 2019 - 6:45pm  complete         NaN
# 157  1544298300   Dec 08 2018 - 7:45pm  complete         NaN
# 239  1548878400   Jan 30 2019 - 8:00pm  complete         NaN
# 77   1538910000  Oct 07 2018 - 11:00am  complete         NaN
#
#              home_team_name     away_team_name         referee  \
# 167  Brighton & Hove Albion            Chelsea  Stuart Attwell
# 317       Tottenham Hotspur     Crystal Palace  Andre Marriner
# 157          Leicester City  Tottenham Hotspur    Craig Pawson
# 239       Tottenham Hotspur            Watford    Graham Scott
# 77                   Fulham            Arsenal    Paul Tierney
#
#      Pre-Match PPG (Home)  Pre-Match PPG (Away)  home_ppg  ...  \
# 167                  2.00                  1.86      1.21  ...
# 317                  2.00                  1.33      2.00  ...
# 157                  1.57                  2.33      1.42  ...
# 239                  1.80                  1.45      2.00  ...
# 77                   1.33                  2.00      1.11  ...
#
#      odds_ft_home_team_win  odds_ft_draw  odds_ft_away_team_win  \
# 167                   7.75          4.40                   1.44
# 317                   1.50          4.45                   6.95
# 157                   4.50          3.75                   1.87
# 239                   1.67          3.90                   5.60
# 77                    5.15          4.35                   1.65
#
#      odds_ft_over15  odds_ft_over25  odds_ft_over35  odds_ft_over45  \
# 167            1.27            1.83            3.15             0.0
# 317            1.20            1.62            2.60             0.0
# 157            1.25            1.80            3.00             0.0
# 239            1.23            1.74            2.85             0.0
# 77             1.13            1.43            2.10             0.0
#
#     odds_btts_yes odds_btts_no  \
# 167          2.00         1.65
# 317          1.74         2.05
# 157          1.62         2.00
# 239          1.71         2.05
# 77           1.48         2.45
#
#                                           stadium_name
# 167  The American Express Community Stadium (Falmer...
# 317                 Tottenham Hotspur Stadium (London)
# 157     King Power Stadium (Leicester- Leicestershire)
# 239                           Wembley Stadium (London)
# 77                             Craven Cottage (London)
#
# [5 rows x 61 columns]

# %%
df_P.shape
# Out:
# (380, 61)

# %%
df_P.columns
# Out:
# Index(['timestamp', 'date_GMT', 'status', 'attendance', 'home_team_name',
#        'away_team_name', 'referee', 'Pre-Match PPG (Home)',
#        'Pre-Match PPG (Away)', 'home_ppg', 'away_ppg', 'home_team_goal_count',
#        'away_team_goal_count', 'total_goal_count', 'total_goals_at_half_time',
#        'home_team_goal_count_half_time', 'away_team_goal_count_half_time',
#        'home_team_goal_timings', 'away_team_goal_timings',
#        'home_team_corner_count', 'away_team_corner_count',
#        'home_team_yellow_cards', 'home_team_red_cards',
#        'away_team_yellow_cards', 'away_team_red_cards',
#        'home_team_first_half_cards', 'home_team_second_half_cards',
#        'away_team_first_half_cards', 'away_team_second_half_cards',
#        'home_team_shots', 'away_team_shots', 'home_team_shots_on_target',
#        'away_team_shots_on_target', 'home_team_shots_off_target',
#        'away_team_shots_off_target', 'home_team_fouls', 'away_team_fouls',
#        'home_team_possession', 'away_team_possession', 'team_a_xg',
#        'team_b_xg', 'average_goals_per_match_pre_match',
#        'btts_percentage_pre_match', 'over_15_percentage_pre_match',
#        'over_25_percentage_pre_match', 'over_35_percentage_pre_match',
#        'over_45_percentage_pre_match', 'over_15_HT_FHG_percentage_pre_match',
#        'over_05_HT_FHG_percentage_pre_match',
#        'average_corners_per_match_pre_match',
#        'average_cards_per_match_pre_match', 'odds_ft_home_team_win',
#        'odds_ft_draw', 'odds_ft_away_team_win', 'odds_ft_over15',
#        'odds_ft_over25', 'odds_ft_over35', 'odds_ft_over45', 'odds_btts_yes',
#        'odds_btts_no', 'stadium_name'],
#       dtype='object')

# %%
df_P.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 61 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   timestamp                            380 non-null    int64
#  1   date_GMT                             380 non-null    object
#  2   status                               380 non-null    object
#  3   attendance                           0 non-null      float64
#  4   home_team_name                       380 non-null    object
#  5   away_team_name                       380 non-null    object
#  6   referee                              380 non-null    object
#  7   Pre-Match PPG (Home)                 380 non-null    float64
#  8   Pre-Match PPG (Away)                 380 non-null    float64
#  9   home_ppg                             380 non-null    float64
#  10  away_ppg                             380 non-null    float64
#  11  home_team_goal_count                 380 non-null    int64
#  12  away_team_goal_count                 380 non-null    int64
#  13  total_goal_count                     380 non-null    int64
#  14  total_goals_at_half_time             380 non-null    int64
#  15  home_team_goal_count_half_time       380 non-null    int64
#  16  away_team_goal_count_half_time       380 non-null    int64
#  17  home_team_goal_timings               292 non-null    object
#  18  away_team_goal_timings               261 non-null    object
#  19  home_team_corner_count               380 non-null    int64
#  20  away_team_corner_count               380 non-null    int64
#  21  home_team_yellow_cards               380 non-null    int64
#  22  home_team_red_cards                  380 non-null    int64
#  23  away_team_yellow_cards               380 non-null    int64
#  24  away_team_red_cards                  380 non-null    int64
#  25  home_team_first_half_cards           380 non-null    int64
#  26  home_team_second_half_cards          380 non-null    int64
#  27  away_team_first_half_cards           380 non-null    int64
#  28  away_team_second_half_cards          380 non-null    int64
#  29  home_team_shots                      380 non-null    int64
#  30  away_team_shots                      380 non-null    int64
#  31  home_team_shots_on_target            380 non-null    int64
#  32  away_team_shots_on_target            380 non-null    int64
#  33  home_team_shots_off_target           380 non-null    int64
#  34  away_team_shots_off_target           380 non-null    int64
#  35  home_team_fouls                      380 non-null    int64
#  36  away_team_fouls                      380 non-null    int64
#  37  home_team_possession                 380 non-null    int64
#  38  away_team_possession                 380 non-null    int64
#  39  team_a_xg                            380 non-null    float64
#  40  team_b_xg                            380 non-null    float64
#  41  average_goals_per_match_pre_match    380 non-null    float64
#  42  btts_percentage_pre_match            380 non-null    int64
#  43  over_15_percentage_pre_match         380 non-null    int64
#  44  over_25_percentage_pre_match         380 non-null    int64
#  45  over_35_percentage_pre_match         380 non-null    int64
#  46  over_45_percentage_pre_match         380 non-null    int64
#  47  over_15_HT_FHG_percentage_pre_match  380 non-null    int64
#  48  over_05_HT_FHG_percentage_pre_match  380 non-null    int64
#  49  average_corners_per_match_pre_match  380 non-null    float64
#  50  average_cards_per_match_pre_match    380 non-null    float64
#  51  odds_ft_home_team_win                380 non-null    float64
#  52  odds_ft_draw                         380 non-null    float64
#  53  odds_ft_away_team_win                380 non-null    float64
#  54  odds_ft_over15                       380 non-null    float64
#  55  odds_ft_over25                       380 non-null    float64
#  56  odds_ft_over35                       380 non-null    float64
#  57  odds_ft_over45                       380 non-null    float64
#  58  odds_btts_yes                        380 non-null    float64
#  59  odds_btts_no                         380 non-null    float64
#  60  stadium_name                         380 non-null    object
# dtypes: float64(19), int64(34), object(8)
# memory usage: 181.2+ KB

# %%
## Coluna para a distribuição de Poisson
coluna = 'total_goal_count'

coluna_analisada = df_P[coluna].copy()

# %%
## Valores únicos
coluna_analisada.unique()
# Out:
# array([3, 2, 4, 0, 5, 7, 1, 6, 8])

# %%
## Características da coluna de interesse
coluna_analisada.describe()
# Out:
# count    380.000000
# mean       2.821053
# std        1.601312
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        8.000000
# Name: total_goal_count, dtype: float64

# %%
# Visualizando os gols por partida - Histograma
histograma(coluna, coluna_analisada.mean(),
           coluna_analisada.std(), bins=9)

# %%
coluna_analisada.value_counts()
# Out:
# 2    99
# 3    84
# 4    65
# 1    55
# 5    32
# 0    22
# 6    16
# 7     5
# 8     2
# Name: total_goal_count, dtype: int64

# %%
df_P.shape
# Out:
# (380, 61)

# %%
# Chance de ter mais que 3 gols em um jogo
(65+32+16+5+2)/380
# Out:
# 0.3157894736842105

# %% [markdown]
# # **Distribuições discretas**

# %% [markdown]
# ## **Poisson**
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.poisson.html

# %% [markdown]
# \begin{equation}
#   P(X=k) = \frac{\lambda^k \; e^{-\lambda}}{k!}
# \end{equation}
#
# https://pt.wikipedia.org/wiki/Distribui%C3%A7%C3%A3o_de_Poisson

# %%
from scipy.stats import poisson

# %%
df_P.shape
# Out:
# (380, 61)

# %% [markdown]
# ## **Gols do time da casa**

# %%
## Utilizando os gols do time da casa
coluna = 'home_team_goal_count'
media = df_P[coluna].mean()
DP = df_P[coluna].std()

df_P['dadosPoisson'] = poisson.rvs(mu=media, size=380)

# %%
df_P[coluna].unique()
# Out:
# array([2, 1, 0, 4, 3, 6, 5])

# %%
## Histograma do dados gerados por Poisson
histograma('dadosPoisson', media, DP, 7)

# %%
## Histograma do dados reais
histograma(coluna, media, DP, 7)

# %% [markdown]
# ### **Ajustando uma distribuição de Poisson**

# %%
golsPoisson = []

for k in range(7):
    golsPoisson.append(poisson.pmf(k, media))

## probabilidades estimadas a partir da média dos dados
golsPoisson
# Out:
# [0.20837393422286224,
#  0.326818065254805,
#  0.2562941669629787,
#  0.13399238904380287,
#  0.052539120967175335,
#  0.016480692682335013,
#  0.0043081108941542354]

# %%
## Comparação entre dados reais e ajuste da distribuição
golsReais, bin_limites = np.histogram(df_P[coluna], bins=7)

df_Gols = pd.DataFrame(golsReais/380, columns=['Verdadeiros'])
df_Gols['Poisson'] = golsPoisson

df_Gols
# Out:
#    Verdadeiros   Poisson
# 0     0.231579  0.208374
# 1     0.305263  0.326818
# 2     0.250000  0.256294
# 3     0.126316  0.133992
# 4     0.057895  0.052539
# 5     0.021053  0.016481
# 6     0.007895  0.004308

# %%
df_Gols.Verdadeiros.sum()
# Out:
# 1.0

# %%
df_Gols.Poisson.sum()
# Out:
# 0.9988064800281135

# %% [markdown]
# ### **Ajustando uma distribuição Binomial**

# %%
from scipy.stats import binom

golsBinomial = []
pNGol = 0.231579

for k in range(7):
    golsBinomial.append(binom.pmf(k, 7, pNGol))

## probabilidades estimadas a partir da media dos dados
golsBinomial
# Out:
# [0.15819566396060122,
#  0.33372793774548637,
#  0.3017267178870514,
#  0.1515522775526382,
#  0.045673302634054,
#  0.008258736617576768,
#  0.0008296450197490744]

# %%
df_Gols['Binomial'] = golsBinomial
df_Gols
# Out:
#    Verdadeiros   Poisson  Binomial
# 0     0.231579  0.208374  0.158196
# 1     0.305263  0.326818  0.333728
# 2     0.250000  0.256294  0.301727
# 3     0.126316  0.133992  0.151552
# 4     0.057895  0.052539  0.045673
# 5     0.021053  0.016481  0.008259
# 6     0.007895  0.004308  0.000830

# %%
df_Gols.Binomial.sum()
# Out:
# 0.9999642814171571

# %% [markdown]
# ### **Ajuste da distribuição usando curve_fit**

# %%
### Bibliotecas
from scipy.optimize import curve_fit
from scipy.special import factorial

# %%
### Dados Reais
dados = df_P[coluna]

### Criar números inteiros para a análise de Poisson
bins = np.arange(8) - 0.5

### Configurando a figura de comparação
plt.figure(figsize=(8, 8))

### Dados para o ajuste
estimativas, bin_limites, elementos = plt.hist(dados, bins=bins,
                                               label='Dados Reais')

### Determinar o centro de cada bin
bin_medios = 0.5 * (bin_limites[1:] + bin_limites[:-1])

### Definir uma função de Poisson geral para ajuste
def fit_function(k,lamb):
    '''Ajuste do parâmetro lambda de Poisson'''
    return poisson.pmf(k, lamb)

### Fazendo o ajuste da função
### o comando curve_fit --> utiliza como entrada os bin_medios (inteiros - Poisson)
### estimativas, varia a média lambda para reduzir o erro - intrinsecamente
parametros, cov_matriz = curve_fit(fit_function, bin_medios, estimativas/380)

### Visualização sobreposta
x_plot = np.arange(0,7)
plt.plot(x_plot, fit_function(x_plot,*parametros)*380, marker='o',
         linestyle='', label='Ajuste')

plt.legend()
plt.show()

# %%
### Dados Reais
dados = df_P[coluna]

### Criar números inteiros para a análise de Poisson
bins = np.arange(8) - 0.5

### Configurando a figura de comparação
plt.figure(figsize=(8, 8))

### Dados para o ajuste
estimativas, bin_limites, elementos = plt.hist(dados, bins=bins,
                                               label='Dados Reais')

### Determinar o centro de cada bin
bin_medios = 0.5 * (bin_limites[1:] + bin_limites[:-1])

### Definir uma função de Poisson geral para ajuste
def fit_function(k, n, p):
    '''Ajuste do parâmetro p da Binomial'''
    return binom.pmf(k, n, p)

### Fazendo o ajuste da função
### o comando curve_fit --> utiliza como entrada os bin_medios (inteiros)
### estimativas, varia a probabilidade p para reduzir o erro - intrinsecamente
parametros, cov_matriz = curve_fit(fit_function, bin_medios, estimativas/380, bounds=(0, [6, 0.3]))

### Visualização sobreposta
x_plot = np.arange(0, 7)
plt.plot(x_plot, fit_function(x_plot, *parametros)*380, marker='o',
         linestyle='', label='Ajuste')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-df713ac297f2> in <cell line: 25>()
#      23 ### o comando curve_fit --> utiliza como entrada os bin_medios (inteiros)
#      24 ### estimativas, varia a probabilidade p para reduzir o erro - intrinsecamente
# ---> 25 parametros, cov_matriz = curve_fit(fit_function, bin_medios, estimativas/380, bounds=(0, [6, 0.3]))
#      26
#      27 ### Visualização sobreposta
#
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_minpack_py.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     972             kwargs['max_nfev'] = kwargs.pop('maxfev', None)
#     973
# --> 974         res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#     975                             **kwargs)
#     976
#
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_lsq/least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     936
#     937     elif method == 'trf':
# --> 938         result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     939                      gtol, max_nfev, x_scale, loss_function, tr_solver,
#     940                      tr_options.copy(), verbose)
#
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_lsq/trf.py in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     121             loss_function, tr_solver, tr_options, verbose)
#     122     else:
# --> 123         return trf_bounds(
#     124             fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale,
#     125             loss_function, tr_solver, tr_options, verbose)
#
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_lsq/trf.py in trf_bounds(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     299             J_h = J_augmented[:m]  # Memory view.
#     300             J_augmented[m:] = np.diag(diag_h**0.5)
# --> 301             U, s, V = svd(J_augmented, full_matrices=False)
#     302             V = V.T
#     303             uf = U.T.dot(f_augmented)
#
# /usr/local/lib/python3.10/dist-packages/scipy/linalg/_decomp_svd.py in svd(a, full_matrices, compute_uv, overwrite_a, check_finite, lapack_driver)
#     106
#     107     """
# --> 108     a1 = _asarray_validated(a, check_finite=check_finite)
#     109     if len(a1.shape) != 2:
#     110         raise ValueError('expected matrix')
#
# /usr/local/lib/python3.10/dist-packages/scipy/_lib/_util.py in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     238             raise ValueError('masked arrays are not supported')
#     239     toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 240     a = toarray(a)
#     241     if not objects_ok:
#     242         if a.dtype is np.dtype('O'):
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     625     a = asarray(a, dtype=dtype, order=order)
#     626     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 627         raise ValueError(
#     628             "array must not contain infs or NaNs")
#     629     return a
#
# ValueError: array must not contain infs or NaNs

# %%
parametros
# Out:
# array([1.53025366])

# %%
df_P[coluna].mean()
# Out:
# 1.568421052631579

# %%
## Probabilidade de um jogo ter 3 ou mais gols do time da casa
poisson.sf(3, mu=parametros[0])
# Out:
# 0.06949685319228363

# %% [markdown]
# ## **Total de Gols**

# %%
## Utilizando Total de Gols

# %% [markdown]
# ### **Ajustando uma distribuição de Poisson**

# %%
golsPoisson = []

for k in range(7):
    golsPoisson.append(poisson.pmf(k, media))

## probabilidades estimadas a partir da média dos dados
golsPoisson

# %%
## Comparação entre dados reais e ajuste da distribuição

# %% [markdown]
# ### **Ajustando uma distribuição Binomial**

# %%
from scipy.stats import binom

golsBinomial = []
pNGol = 0.231579

for k in range(7):
    golsBinomial.append(binom.pmf(k, 7, pNGol))

## probabilidades estimadas a partir da media dos dados
golsBinomial

# %% [markdown]
# ### **Ajuste da distribuição usando curve_fit**

# %%
### Bibliotecas
from scipy.optimize import curve_fit
from scipy.special import factorial

# %%
### Dados Reais
dados = df_P[coluna]

### Criar números inteiros para a análise de Poisson
bins = np.arange(8) - 0.5

### Configurando a figura de comparação
plt.figure(figsize=(8, 8))

### Dados para o ajuste
estimativas, bin_limites, elementos = plt.hist(dados, bins=bins,
                                               label='Dados Reais')

### Determinar o centro de cada bin
bin_medios = 0.5 * (bin_limites[1:] + bin_limites[:-1])

### Definir uma função de Poisson geral para ajuste
def fit_function(k,lamb):
    '''Ajuste do parâmetro lambda de Poisson'''
    return poisson.pmf(k, lamb)

### Fazendo o ajuste da função
### o comando curve_fit --> utiliza como entrada os bin_medios (inteiros - Poisson)
### estimativas, varia a média lambda para reduzir o erro - intrinsecamente
parametros, cov_matriz = curve_fit(fit_function, bin_medios, estimativas/380)

### Visualização sobreposta
x_plot = np.arange(0,7)
plt.plot(x_plot, fit_function(x_plot,*parametros)*380, marker='o',
         linestyle='', label='Ajuste')

plt.legend()
plt.show()

# %%
## Probabilidade de um jogo ter 3 ou mais gols totais

# %%
## Utilizando Total de gols

# %%
## Histograma do dados gerados por Poisson

# %%
## Histograma do dados reais

# %% [markdown]
# # **Exercício adicional**

# %% [markdown]
# 1.   Qual a probabilidade de um time ter sequência de 4V, 2E e 2D em 8 jogos em casa?
# 2.   Qual a probabilidade de uma sequência de 4V em 5 jogos fora de casa?
# 3.   E para uma sequência de 3 jogos em casa (2V e 1E) e 3 jogos fora de casa (1V, 1E e 1D)?

# %% [markdown]
# Para o campeonato como um todo temos $N$ jogos com três possibilidades de resultados $V$ - vitória, $E$ - empate e $D$ - derrota. O resultado de cada jogo pode ser modelado como uma variável aleatória $X$, sendo que $p_V$ indica a probabilidade de um determinado jogo resultar em vitória $X_V$. A função massa de probabildaide (**PMF**):
#
# $P(x_V,x_E,x_D \vert N,p_V,p_E,p_D) = P(X_V = x_V,X_E = x_E,X_D = x_D)$
#  : \begin{cases} { \displaystyle {N! \over x_V! x_E! x_D!}p_V^{x_V}\times p_E^{x_E}\times p_D^{x_D}}, \quad &
# \text{onde:} \sum_{i=1}^3 x_i=N \\  \\
# 0 & \text{caso contrário} \end{cases}

# %%
df_T.head(3)
# Out:
#               team_name        common_name     season  country  \
# 0            Arsenal FC            Arsenal  2018/2019  England
# 1  Tottenham Hotspur FC  Tottenham Hotspur  2018/2019  England
# 2    Manchester City FC    Manchester City  2018/2019  England
#
#    matches_played  matches_played_home  matches_played_away  \
# 0              38                   19                   19
# 1              38                   19                   19
# 2              38                   19                   19
#
#    suspended_matches  wins  wins_home  ...  goals_scored_min_81_to_90  \
# 0                  0    21         14  ...                         13
# 1                  0    23         12  ...                         10
# 2                  0    32         18  ...                         10
#
#    goals_conceded_min_0_to_10  goals_conceded_min_11_to_20  \
# 0                           3                            7
# 1                           3                            4
# 2                           0                            2
#
#    goals_conceded_min_21_to_30  goals_conceded_min_31_to_40  \
# 0                            5                            5
# 1                            1                            2
# 2                            3                            3
#
#    goals_conceded_min_41_to_50  goals_conceded_min_51_to_60  \
# 0                            9                            1
# 1                            1                            6
# 2                            3                            3
#
#    goals_conceded_min_61_to_70  goals_conceded_min_71_to_80  \
# 0                           12                            1
# 1                            4                            8
# 2                            4                            2
#
#    goals_conceded_min_81_to_90
# 0                            8
# 1                           10
# 2                            3
#
# [3 rows x 280 columns]

# %%
df_T.columns[:25]
# Out:
# Index(['team_name', 'common_name', 'season', 'country', 'matches_played',
#        'matches_played_home', 'matches_played_away', 'suspended_matches',
#        'wins', 'wins_home', 'wins_away', 'draws', 'draws_home', 'draws_away',
#        'losses', 'losses_home', 'losses_away', 'points_per_game',
#        'points_per_game_home', 'points_per_game_away', 'league_position',
#        'league_position_home', 'league_position_away', 'performance_rank',
#        'goals_scored'],
#       dtype='object')

# %%
NV_casa = df_T['wins_home'].sum()
NE_casa = df_T['draws_home'].sum()
ND_casa = df_T['losses_home'].sum()

NV_casa, NE_casa, ND_casa, np.sum((NV_casa, NE_casa, ND_casa))
# Out:
# (181, 71, 128, 380)

# %%
# Probabilidades - Casa
pV_casa = NV_casa/380
pE_casa = NE_casa/380
pD_casa = ND_casa/380

pV_casa, pE_casa, pD_casa
# Out:
# (0.4763157894736842, 0.1868421052631579, 0.3368421052631579)

# %%
NV_fora = df_T['wins_away'].sum()
NE_fora = df_T['draws_away'].sum()
ND_fora = df_T['losses_away'].sum()

NV_fora, NE_fora, ND_fora, np.sum((NV_fora, NE_fora, ND_fora))
# Out:
# (128, 71, 181, 380)

# %%
# Probabilidades - Fora
pV_fora = NV_fora/380
pE_fora = NE_fora/380
pD_fora = ND_fora/380

pV_fora, pE_fora, pD_fora
# Out:
# (0.3368421052631579, 0.1868421052631579, 0.4763157894736842)

# %% [markdown]
# **Sequência de 4V, 2E e 2D em 8 jogos em casa**

# %%
from scipy.stats import multinomial

multinomial.pmf([4, 2, 2], n=8, p=[pV_casa, pE_casa, pD_casa])
# Out:
# 0.08563108634701937

# %%
# Outra forma
rv = multinomial(8, [pV_casa, pE_casa, pD_casa])
rv.pmf([4, 2, 2])
# Out:
# 0.08563108634701937

# %%
# ERRADO !!!
binom.pmf(4, 8, pV_casa)*binom.pmf(2, 8, pE_casa)*binom.pmf(2, 8, pD_casa)
# Out:
# 0.02069308048764945

# %% [markdown]
# **Sequência de 4V em 5 jogos fora de casa**

# %%
# 4V, 1E e 0D ou 4V, 0E e 1D
multinomial.pmf([4, 1, 0], n=5, p=[pV_fora, pE_fora, pD_fora]) + multinomial.pmf([4, 0, 1], n=5, p=[pV_fora, pE_fora, pD_fora])

# %%
# Outra forma
rv = multinomial(5, [pV_fora, pE_fora, pD_fora])
rv.pmf([4, 1, 0]) + rv.pmf([4, 0, 1])

# %% [markdown]
# **Sequência 3 jogos em casa (2V e 1E) e 3 jogos fora de casa (1V, 1E e 1D)**

# %%
# 2V e 1E em casa
seq_casa = multinomial.pmf([2, 1, 0], n=3, p=[pV_casa, pE_casa, pD_casa])
seq_casa

# %%
# 1V, 1E e 1D fora de casa
seq_fora = multinomial.pmf([1, 1, 1], n=3, p=[pV_fora, pE_fora, pD_fora])
seq_fora

# %%
seq_casa*seq_fora

# %% [markdown]
# # **Referências**

# %% [markdown]
# http://users.stat.ufl.edu/~winner/cases.html

# %% [markdown]
# https://www.anac.gov.br/acesso-a-informacao/dados-abertos/areas-de-atuacao/voos-e-operacoes-aereas/percentuais-de-atrasos-e-cancelamentos

# %% [markdown]
# https://www.youtube.com/watch?v=UrOXRvG9oYE&t=24s
