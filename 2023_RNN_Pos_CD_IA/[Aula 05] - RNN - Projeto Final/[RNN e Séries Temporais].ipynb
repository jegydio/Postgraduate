# %% [markdown]
# # Redes Neurais Recorrentes e Séries Temporais
#
# Trabalho Final: Previsão de séries temporais.
#
# Prof. Dr. Vitor Alex Oliveira Alves
#
# Prof. Me. Jones Eduardo Egydio

# %% [markdown]
# ## Componentes do grupo:
# 1. Nome/RA:
# 2. Nome/RA:
# 3. Nome/RA:
# 4. Nome/RA:

# %% [markdown]
# ## Enunciado.
#
# Utilizando o dataset [*Time Series analysis on Australia rain*](https://www.kaggle.com/code/sudhakordassubeen/time-series-analysis-on-australia-rain/input), realize uma previsão para chuva para os próximos 15 dias. Faça uma quebra no dataset para gerar dados de treino e teste.
#
# Para tal, utilize algumas ferramentas para realizar previsões e medir a qualidade destas previsões. Faça uso de ferramentas vistas para analisar séries temporais vistas em aula, como:
#
# - Métodos simples de previsão;
#
# - Formas de simplificar a tarefa de previsão usando transformações e ajustes dos dados;
#
# - Métodos para avaliar a qualidade de previsões e desempenho de um modelo;
#
# - Técnicas para calcular intervalos de confiança;
#
# - Técnica para identificar anomalia do tipo *outlier*.
#
# Lembrando que os métodos simples para realizar previsões são:
#
# 1. Método base;
# 2. Método base para dados com sazonalidade;
# 3. Método de tendência;
# 4. Média móvel;
# 5. Média móvel ponderada.
#
# O uso desses métodos nos permite:
#
# - Determinar tendências;
# - Identificar anomalias do tipo *outlier* ;
# - Realizar previsões.
#
# Por fim, implemente uma RNN e compare os resultados obtidos com os demais métodos já calculados.
#
# Justifique seus resultados.

# %% [markdown]
# ## Solução
